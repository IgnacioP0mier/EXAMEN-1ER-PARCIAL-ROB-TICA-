# %% [markdown]
# # **Definiciοn de matrices**

# %% [markdown]
# <limit lower="-3.14" upper="3.14" effort="10.0" velocity="1.0"/>

# %%
# %pip install sympy
from IPython.display import display, Markdown
# Out:
# Requirement already satisfied: sympy in /home/franco/Desktop/Robotica/CSpruebaws/.venv/lib/python3.12/site-packages (1.14.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/franco/Desktop/Robotica/CSpruebaws/.venv/lib/python3.12/site-packages (from sympy) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import sympy as sp

theta = sp.Symbol('q1')
d     = 3
a     = 0
alpha = -sp.pi/2


T1 = sp.Matrix([
    [sp.cos(theta), -sp.sin(theta)*sp.cos(alpha),  sp.sin(theta)*sp.sin(alpha), a*sp.cos(theta)],
    [sp.sin(theta),  sp.cos(theta)*sp.cos(alpha), -sp.cos(theta)*sp.sin(alpha), a*sp.sin(theta)],
    [0,              sp.sin(alpha),               sp.cos(alpha),                d],
    [0,              0,                           0,                            1]
])

sp.pprint(T1, use_unicode=True)
# Out:
# ⎡cos(q₁)  0   -sin(q₁)  0⎤
# ⎢                        ⎥
# ⎢sin(q₁)  0   cos(q₁)   0⎥
# ⎢                        ⎥
# ⎢   0     -1     0      3⎥
# ⎢                        ⎥
# ⎣   0     0      0      1⎦

# %%
import sympy as sp

theta = sp.Symbol('q2')
d     = 0
a     = 1.5
alpha = 0


T2 = sp.Matrix([
    [sp.cos(theta), -sp.sin(theta)*sp.cos(alpha),  sp.sin(theta)*sp.sin(alpha), a*sp.cos(theta)],
    [sp.sin(theta),  sp.cos(theta)*sp.cos(alpha), -sp.cos(theta)*sp.sin(alpha), a*sp.sin(theta)],
    [0,              sp.sin(alpha),               sp.cos(alpha),                d],
    [0,              0,                           0,                            1]
])

sp.pprint(T2, use_unicode=True)
# Out:
# ⎡cos(q₂)  -sin(q₂)  0  1.5⋅cos(q₂)⎤
# ⎢                                 ⎥
# ⎢sin(q₂)  cos(q₂)   0  1.5⋅sin(q₂)⎥
# ⎢                                 ⎥
# ⎢   0        0      1       0     ⎥
# ⎢                                 ⎥
# ⎣   0        0      0       1     ⎦

# %%
import sympy as sp

theta = sp.Symbol('q3')
d     = 0
a     = 1.5
alpha = 0


T3 = sp.Matrix([
    [sp.cos(theta), -sp.sin(theta)*sp.cos(alpha),  sp.sin(theta)*sp.sin(alpha), a*sp.cos(theta)],
    [sp.sin(theta),  sp.cos(theta)*sp.cos(alpha), -sp.cos(theta)*sp.sin(alpha), a*sp.sin(theta)],
    [0,              sp.sin(alpha),               sp.cos(alpha),                d],
    [0,              0,                           0,                            1]
])

sp.pprint(T3, use_unicode=True)
# Out:
# ⎡cos(q₃)  -sin(q₃)  0  1.5⋅cos(q₃)⎤
# ⎢                                 ⎥
# ⎢sin(q₃)  cos(q₃)   0  1.5⋅sin(q₃)⎥
# ⎢                                 ⎥
# ⎢   0        0      1       0     ⎥
# ⎢                                 ⎥
# ⎣   0        0      0       1     ⎦

# %%
T = T1 @ T2 @ T3 
print(sp.sstr(T))
# Out:
# Matrix([
# [-sin(q2)*sin(q3)*cos(q1) + cos(q1)*cos(q2)*cos(q3), -sin(q2)*cos(q1)*cos(q3) - sin(q3)*cos(q1)*cos(q2), -sin(q1), -1.5*sin(q2)*sin(q3)*cos(q1) + 1.5*cos(q1)*cos(q2)*cos(q3) + 1.5*cos(q1)*cos(q2)],
# [-sin(q1)*sin(q2)*sin(q3) + sin(q1)*cos(q2)*cos(q3), -sin(q1)*sin(q2)*cos(q3) - sin(q1)*sin(q3)*cos(q2),  cos(q1), -1.5*sin(q1)*sin(q2)*sin(q3) + 1.5*sin(q1)*cos(q2)*cos(q3) + 1.5*sin(q1)*cos(q2)],
# [                -sin(q2)*cos(q3) - sin(q3)*cos(q2),                  sin(q2)*sin(q3) - cos(q2)*cos(q3),        0,                     -1.5*sin(q2)*cos(q3) - 1.5*sin(q2) - 1.5*sin(q3)*cos(q2) + 3],
# [                                                 0,                                                  0,        0,                                                                                1]])

# %%
T_final = sp.simplify(T)
print(sp.sstr(T_final))
# Out:
# Matrix([
# [cos(q1)*cos(q2 + q3), -sin(q2 + q3)*cos(q1), -sin(q1),  1.5*(cos(q2) + cos(q2 + q3))*cos(q1)],
# [sin(q1)*cos(q2 + q3), -sin(q1)*sin(q2 + q3),  cos(q1),  1.5*(cos(q2) + cos(q2 + q3))*sin(q1)],
# [       -sin(q2 + q3),         -cos(q2 + q3),        0, -1.5*sin(q2) - 1.5*sin(q2 + q3) + 3.0],
# [                   0,                     0,        0,                                     1]])

# %% [markdown]
# # **Puntos**

# %% [markdown]
# **Posición en X**

# %%
T_final[0,3]
# Out:
# 1.5*(cos(q2) + cos(q2 + q3))*cos(q1)

# %% [markdown]
# **Posición en Y**

# %%
T_final[1,3]
# Out:
# 1.5*(cos(q2) + cos(q2 + q3))*sin(q1)

# %% [markdown]
# **Posición en Z**

# %%
T_final[2,3]
# Out:
# 1.5*sin(q2) + 1.5*sin(q2 + q3) + 3.0

# %%
import sympy as sp

valores = {
    sp.Symbol('q1'): 0,
    sp.Symbol('q2'): 0,
    sp.Symbol('q3'): 0,
    sp.Symbol('q4'): 0,
    
    sp.Symbol('l1'): 2,
    sp.Symbol('l2'): 1.5,
    sp.Symbol('l3'): 0.8,
    sp.Symbol('l4'): 0
}

Px = T_final[0,3].evalf(subs=valores)
Py = T_final[1,3].evalf(subs=valores)
Pz = T_final[2,3].evalf(subs=valores)

Px, Py, Pz
# Out:
# (4.30000000000000, 0, 0)

# %% [markdown]
# # **Matriz Jacobiana (inversa)**

# %%
import sympy as sp

x = sp.simplify(T_final[0,3])
y = sp.simplify(T_final[1,3])
z = sp.simplify(T_final[2,3])

pos = sp.Matrix([x, y, z])

simbolos = {str(s): s for s in T_final.free_symbols}

q1_ = simbolos['q1']
q2_ = simbolos['q2']
q3_ = simbolos['q3']

Jv = sp.simplify(pos.jacobian([q1_, q2_, q3_]))

print("Vector de posición:")
sp.pprint(pos, use_unicode=True)

print("\nJacobiana lineal Jv:")
sp.pprint(Jv, use_unicode=True)
# Out:
# Vector de posición:
# ⎡1.5⋅(cos(q₂) + cos(q₂ + q₃))⋅cos(q₁) ⎤
# ⎢                                     ⎥
# ⎢1.5⋅(cos(q₂) + cos(q₂ + q₃))⋅sin(q₁) ⎥
# ⎢                                     ⎥
# ⎣-1.5⋅sin(q₂) - 1.5⋅sin(q₂ + q₃) + 3.0⎦
#
# Jacobiana lineal Jv:
# ⎡-1.5⋅(cos(q₂) + cos(q₂ + q₃))⋅sin(q₁)  -1.5⋅(sin(q₂) + sin(q₂ + q₃))⋅cos(q₁)  ↪
# ⎢                                                                              ↪
# ⎢1.5⋅(cos(q₂) + cos(q₂ + q₃))⋅cos(q₁)   -1.5⋅(sin(q₂) + sin(q₂ + q₃))⋅sin(q₁)  ↪
# ⎢                                                                              ↪
# ⎣                  0                       -1.5⋅cos(q₂) - 1.5⋅cos(q₂ + q₃)     ↪
#
# ↪  -1.5⋅sin(q₂ + q₃)⋅cos(q₁)⎤
# ↪                           ⎥
# ↪  -1.5⋅sin(q₁)⋅sin(q₂ + q₃)⎥
# ↪                           ⎥
# ↪      -1.5⋅cos(q₂ + q₃)    ⎦
